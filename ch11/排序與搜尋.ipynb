# %%
def showdata(data_list):
    for i in range(len(data_list)):
        print('%3d' %data_list[i],end='')
    print()

data=[16,25,39,63,27,12,8,45]	                # 原始資料 
print('氣泡排序法：原始資料為：')
showdata(data)

n = len(data)

for i in range(1, n):                           #掃描次數
    for j in range(n-i):
        if data[j]>data[j+1]:                   #比較,交換的次數
            data[j],data[j+1]=data[j+1],data[j] #比較相鄰兩數,如果第一數較大則交換
    print('第 %d 次掃描後的結果是：' %i,end='') #把各次掃描後的結果印出
    showdata(data)
	
print('排序後結果為：')
showdata(data)
# Out:
# 氣泡排序法：原始資料為：
#  16 25 39 63 27 12  8 45
# 第 1 次掃描後的結果是： 16 25 39 27 12  8 45 63
# 第 2 次掃描後的結果是： 16 25 27 12  8 39 45 63
# 第 3 次掃描後的結果是： 16 25 12  8 27 39 45 63
# 第 4 次掃描後的結果是： 16 12  8 25 27 39 45 63
# 第 5 次掃描後的結果是： 12  8 16 25 27 39 45 63
# 第 6 次掃描後的結果是：  8 12 16 25 27 39 45 63
# 第 7 次掃描後的結果是：  8 12 16 25 27 39 45 63
# 排序後結果為：
#   8 12 16 25 27 39 45 63

# %%
cars=["Audi", "Honda", "Mazda", "Ford", "Benz", "Lexus", "BMW"]
print('氣泡排序法,原始資料為：', cars, sep='')

n = len(cars)

for i in range(1, n):                                           #掃描次數
    for j in range(n-i):
        if cars[j]>cars[j+1]:                                   #比較,交換的次數
            cars[j],cars[j+1]=cars[j+1],cars[j]                 #比較相鄰資料,如果第一筆資料較大則交換
    print('第 %d 次掃描後的結果是：' %i,end='')                 #把各次掃描後的結果印出
    print(cars)
	
print('氣泡排序之後的資料為：', cars)
# Out:
# 氣泡排序法,原始資料為：['Audi', 'Honda', 'Mazda', 'Ford', 'Benz', 'Lexus', 'BMW']
# 第 1 次掃描後的結果是：['Audi', 'Honda', 'Ford', 'Benz', 'Lexus', 'BMW', 'Mazda']
# 第 2 次掃描後的結果是：['Audi', 'Ford', 'Benz', 'Honda', 'BMW', 'Lexus', 'Mazda']
# 第 3 次掃描後的結果是：['Audi', 'Benz', 'Ford', 'BMW', 'Honda', 'Lexus', 'Mazda']
# 第 4 次掃描後的結果是：['Audi', 'Benz', 'BMW', 'Ford', 'Honda', 'Lexus', 'Mazda']
# 第 5 次掃描後的結果是：['Audi', 'BMW', 'Benz', 'Ford', 'Honda', 'Lexus', 'Mazda']
# 第 6 次掃描後的結果是：['Audi', 'BMW', 'Benz', 'Ford', 'Honda', 'Lexus', 'Mazda']
# 氣泡排序之後的資料為： ['Audi', 'BMW', 'Benz', 'Ford', 'Honda', 'Lexus', 'Mazda']

# %%
def showdata(data_list):
    for i in range(len(data_list)):
        print('%3d' %data_list[i],end='')
    print()

data=[16,25,39,63,27,12,8,45]
print('選擇排序法:原始資料為：')
showdata(data)

n = len(data)

for i in range(n-1):
    minIdx = i
    for j in range(i+1, n):
        if(data[j]<data[minIdx]):
            minIdx = j
    data[i], data[minIdx] = data[minIdx], data[i]
    print('第 %d 次掃描後的結果是：' %(i+1), end='')
    showdata(data)
	
print('排序後結果為：')
showdata(data)
# Out:
# 選擇排序法:原始資料為：
#  16 25 39 63 27 12  8 45
# 第 1 次掃描後的結果是：  8 25 39 63 27 12 16 45
# 第 2 次掃描後的結果是：  8 12 39 63 27 25 16 45
# 第 3 次掃描後的結果是：  8 12 16 63 27 25 39 45
# 第 4 次掃描後的結果是：  8 12 16 25 27 63 39 45
# 第 5 次掃描後的結果是：  8 12 16 25 27 63 39 45
# 第 6 次掃描後的結果是：  8 12 16 25 27 39 63 45
# 第 7 次掃描後的結果是：  8 12 16 25 27 39 45 63
# 排序後結果為：
#   8 12 16 25 27 39 45 63

# %%
def showdata(data_list):
    print('[', end='')
    for i in range(len(data_list)):
        print(data_list[i],end=' ')
    print(']')
    
class Student:
    def __init__(self, name, age, gpa):
        self.name = name
        self.age = age
        self.gpa = gpa
    def __lt__(self, student2):
        if self.age<student2.age:
            return True
        else:
            return False
    def __str__(self):
        return '%5s(%d,%.1f)'%(self.name,self.age,self.gpa)

data=[Student('Amy', 15, 4.2),
      Student('Bill', 16, 3.8),
      Student('Chris', 13, 4.0),
      Student('David', 19, 4.8),
      Student('Ed', 17, 2.6)]
print('選擇排序法:原始資料為：', end ='')
showdata(data)

n = len(data)

for i in range(n-1):
    minIdx = i
    for j in range(i+1, n):
        if(data[j]<data[minIdx]):
            minIdx = j
    data[i], data[minIdx] = data[minIdx], data[i]
    print('第 %d 次掃描後的結果是：' %(i+1), end ='')
    showdata(data)
	
print('選擇排序之後的資料為：', end =' ')
showdata(data)
# Out:
# 選擇排序法:原始資料為：[  Amy(15,4.2)  Bill(16,3.8) Chris(13,4.0) David(19,4.8)    Ed(17,2.6) ]
# 第 1 次掃描後的結果是：[Chris(13,4.0)  Bill(16,3.8)   Amy(15,4.2) David(19,4.8)    Ed(17,2.6) ]
# 第 2 次掃描後的結果是：[Chris(13,4.0)   Amy(15,4.2)  Bill(16,3.8) David(19,4.8)    Ed(17,2.6) ]
# 第 3 次掃描後的結果是：[Chris(13,4.0)   Amy(15,4.2)  Bill(16,3.8) David(19,4.8)    Ed(17,2.6) ]
# 第 4 次掃描後的結果是：[Chris(13,4.0)   Amy(15,4.2)  Bill(16,3.8)    Ed(17,2.6) David(19,4.8) ]
# 選擇排序之後的資料為： [Chris(13,4.0)   Amy(15,4.2)  Bill(16,3.8)    Ed(17,2.6) David(19,4.8) ]

# %%
def showdata(data_list):
    for i in range(len(data_list)):
        print('%3d' %data_list[i],end='')
    print()

data=[16,25,39,63,27,12,8,45]
print('插入排序法：原始資料為：')
showdata(data)

n = len(data)

for i in range(1, n):
    tmp = data[i]
    for j in range(i):
        if(data[j]>tmp):
            data.insert(j,tmp)            
            del data[i+1]
            break
    print('第 %d 次掃描後的結果是：' %i,end='')
    showdata(data)
	
print('排序後結果為：')
showdata(data)
# Out:
# 插入排序法：原始資料為：
#  16 25 39 63 27 12  8 45
# 第 1 次掃描後的結果是： 16 25 39 63 27 12  8 45
# 第 2 次掃描後的結果是： 16 25 39 63 27 12  8 45
# 第 3 次掃描後的結果是： 16 25 39 63 27 12  8 45
# 第 4 次掃描後的結果是： 16 25 27 39 63 12  8 45
# 第 5 次掃描後的結果是： 12 16 25 27 39 63  8 45
# 第 6 次掃描後的結果是：  8 12 16 25 27 39 63 45
# 第 7 次掃描後的結果是：  8 12 16 25 27 39 45 63
# 排序後結果為：
#   8 12 16 25 27 39 45 63

# %%
def showdata(data_list):
    print('[', end='')
    for i in range(len(data_list)):
        print(data_list[i],end=' ')
    print(']')
    
class Student:
    def __init__(self, name, age, gpa):
        self.name = name
        self.age = age
        self.gpa = gpa
    def __lt__(self, student2):
        if self.gpa<student2.gpa:
            return True
        else:
            return False
    def __str__(self):
        return '%5s(%d,%.1f)'%(self.name,self.age,self.gpa)

data=[Student('Amy', 15, 4.2),
      Student('Bill', 16, 3.8),
      Student('Chris', 13, 4.0),
      Student('David', 19, 4.8),
      Student('Ed', 17, 2.6)]
print('插入排序法,原始資料為：', end='')
showdata(data)

n = len(data)

for i in range(1, n):
    tmp = data[i]
    for j in range(i):
        if(data[j]<tmp):
            data.insert(j,tmp)            
            del data[i+1]
            break
    print('第 %d 次掃描後的結果是：' %i,end='')
    showdata(data)
	
print('插入排序之後的資料為：', end=' ')
showdata(data)
# Out:
# 插入排序法,原始資料為：[  Amy(15,4.2)  Bill(16,3.8) Chris(13,4.0) David(19,4.8)    Ed(17,2.6) ]
# 第 1 次掃描後的結果是：[  Amy(15,4.2)  Bill(16,3.8) Chris(13,4.0) David(19,4.8)    Ed(17,2.6) ]
# 第 2 次掃描後的結果是：[  Amy(15,4.2) Chris(13,4.0)  Bill(16,3.8) David(19,4.8)    Ed(17,2.6) ]
# 第 3 次掃描後的結果是：[David(19,4.8)   Amy(15,4.2) Chris(13,4.0)  Bill(16,3.8)    Ed(17,2.6) ]
# 第 4 次掃描後的結果是：[David(19,4.8)   Amy(15,4.2) Chris(13,4.0)  Bill(16,3.8)    Ed(17,2.6) ]
# 插入排序之後的資料為： [David(19,4.8)   Amy(15,4.2) Chris(13,4.0)  Bill(16,3.8)    Ed(17,2.6) ]

# %%
import random

def showData(data_list):
    for i in range(len(data)//5):
        for j in range(5):
            print('%2d[%3d]  ' %(i*5+j+1,data[i*5+j]),end='')
        print()

val=0
data=[]
while(len(data)<50):
    randNum = random.randint(1,100)
    if(randNum not in data):
        data.append(randNum)

while True:
    val=int(input('請輸入搜尋鍵值(1-100)，輸入-1離開：'))
    if val == -1:
        break
    for i in range(50):
        if data[i]==val:
            print('在第%3d個位置找到鍵值[%3d]' %(i+1,data[i]))
            break
    else:
        print('######[%3d]不存在######' %val)

print('資料內容：')
showData(data)
# Out:
# 請輸入搜尋鍵值(1-100)，輸入-1離開：5
# ######[  5]不存在######
# 請輸入搜尋鍵值(1-100)，輸入-1離開：25
# ######[ 25]不存在######
# 請輸入搜尋鍵值(1-100)，輸入-1離開：60
# ######[ 60]不存在######
# 請輸入搜尋鍵值(1-100)，輸入-1離開：35
# ######[ 35]不存在######
# 請輸入搜尋鍵值(1-100)，輸入-1離開：45
# 在第 12個位置找到鍵值[ 45]
# 請輸入搜尋鍵值(1-100)，輸入-1離開：-1
# 資料內容：
#  1[ 77]   2[ 87]   3[ 89]   4[ 92]   5[ 28]
#  6[ 66]   7[ 97]   8[ 12]   9[ 50]  10[ 14]
# 11[ 34]  12[ 45]  13[ 16]  14[ 85]  15[  4]
# 16[ 20]  17[ 23]  18[ 43]  19[ 61]  20[ 79]
# 21[  6]  22[ 68]  23[ 10]  24[ 39]  25[ 53]
# 26[ 41]  27[  8]  28[ 59]  29[ 57]  30[ 99]
# 31[ 70]  32[ 47]  33[ 48]  34[  3]  35[ 80]
# 36[ 94]  37[ 90]  38[  9]  39[ 78]  40[100]
# 41[  2]  42[ 32]  43[ 91]  44[  7]  45[ 84]
# 46[ 52]  47[ 29]  48[ 69]  49[ 17]  50[ 24]

# %%
'''
Created on 2022年8月12日

@author: xvpow
'''
import random

def showData(data_list):
    for i in range(len(data)//5):
        for j in range(5):
            print('%2d[%3d]  ' %(i*5+j+1,data[i*5+j]),end='')
        print()

val=0
data=[]
while(len(data)<50):
    randNum = random.randint(1,100)
    if(randNum not in data):
        data.append(randNum)
                
print('資料內容：')
showData(data)

while True:
    val=int(input('請輸入搜尋鍵值(1-100)，輸入-1離開：'))
    if val == -1:
        break
    for i in range(50):
        if data[i]==val:
            print('在第%3d個位置找到鍵值[%3d]' %(i+1,data[i]))
            break
    else:
        print('######[%3d]不存在######' %val)
# Out:
# 請輸入搜尋鍵值(1-100)，輸入-1離開：65
# ######[ 65]不存在######
# 請輸入搜尋鍵值(1-100)，輸入-1離開：45
# ######[ 45]不存在######
# 請輸入搜尋鍵值(1-100)，輸入-1離開：20
# ######[ 20]不存在######
# 請輸入搜尋鍵值(1-100)，輸入-1離開：17
# 在第 22個位置找到鍵值[ 17]
# 請輸入搜尋鍵值(1-100)，輸入-1離開：18
# ######[ 18]不存在######
# 請輸入搜尋鍵值(1-100)，輸入-1離開：-1
# 資料內容：
#  1[ 92]   2[ 83]   3[ 56]   4[ 98]   5[ 72]
#  6[  9]   7[ 56]   8[ 32]   9[ 92]  10[ 19]
# 11[ 52]  12[  7]  13[ 84]  14[ 66]  15[ 68]
# 16[ 26]  17[ 91]  18[ 21]  19[ 48]  20[ 10]
# 21[ 64]  22[ 17]  23[100]  24[ 36]  25[ 15]
# 26[ 19]  27[ 10]  28[ 40]  29[ 31]  30[ 92]
# 31[ 53]  32[ 94]  33[ 21]  34[ 98]  35[ 61]
# 36[ 58]  37[ 48]  38[ 41]  39[ 26]  40[ 39]
# 41[ 83]  42[ 83]  43[ 57]  44[ 12]  45[ 64]
# 46[ 77]  47[ 13]  48[ 56]  49[ 25]  50[ 34]

# %%
import random

def showData(data_list):
    for i in range(len(data)//5):
        for j in range(5):
            print('%2d[%3d]  ' %(i*5+j+1,data[i*5+j]),end='')
        print()

def bin_search(data, val):
    low, high = 0, len(data)-1
    mid = -1
    while not low>high:
        mid=(low+high)//2
        if val<data[mid]:
            print('%d 介於最小值 %2d[%3d]及中間值 %2d[%3d]，找左半邊' \
                   %(val,low+1,data[low],mid+1,data[mid]))
            high=mid-1
        elif val>data[mid]:
            print('%d 介於中間值 %2d[%3d]及最大值 %2d[%3d]，找右半邊' \
                  %(val,mid+1,data[mid],high+1,data[high]))
            low=mid+1
        else:
            return mid
    return -1

data=[]
while(len(data)<50):
    randNum = random.randint(1,100)
    if(randNum not in data):
        data.append(randNum)

data.sort()
print('資料內容：')
showData(data)

while True:
    val=int(input('請輸入搜尋鍵值(1-100)，輸入-1結束：'))
    if val ==-1:
        break
    pos=bin_search(data,val)
    if pos==-1:
        print('##### [%3d]不存在 #####' %val)
    else:
        print('在第%2d個位置找到[%3d]' %(pos+1,data[pos]))
# Out:
# 資料內容：
#  1[  1]   2[  3]   3[ 11]   4[ 12]   5[ 13]
#  6[ 14]   7[ 15]   8[ 16]   9[ 17]  10[ 18]
# 11[ 20]  12[ 23]  13[ 25]  14[ 26]  15[ 28]
# 16[ 33]  17[ 35]  18[ 36]  19[ 37]  20[ 38]
# 21[ 39]  22[ 41]  23[ 43]  24[ 44]  25[ 48]
# 26[ 49]  27[ 52]  28[ 53]  29[ 54]  30[ 56]
# 31[ 58]  32[ 60]  33[ 63]  34[ 68]  35[ 69]
# 36[ 76]  37[ 77]  38[ 78]  39[ 80]  40[ 82]
# 41[ 84]  42[ 85]  43[ 86]  44[ 88]  45[ 89]
# 46[ 91]  47[ 94]  48[ 96]  49[ 97]  50[ 98]
# 請輸入搜尋鍵值(1-100)，輸入-1結束：5
# 5 介於最小值  1[  1]及中間值 25[ 48]，找左半邊
# 5 介於最小值  1[  1]及中間值 12[ 23]，找左半邊
# 5 介於最小值  1[  1]及中間值  6[ 14]，找左半邊
# 5 介於最小值  1[  1]及中間值  3[ 11]，找左半邊
# 5 介於中間值  1[  1]及最大值  2[  3]，找右半邊
# 5 介於中間值  2[  3]及最大值  2[  3]，找右半邊
# ##### [  5]不存在 #####
# 請輸入搜尋鍵值(1-100)，輸入-1結束：7
# 7 介於最小值  1[  1]及中間值 25[ 48]，找左半邊
# 7 介於最小值  1[  1]及中間值 12[ 23]，找左半邊
# 7 介於最小值  1[  1]及中間值  6[ 14]，找左半邊
# 7 介於最小值  1[  1]及中間值  3[ 11]，找左半邊
# 7 介於中間值  1[  1]及最大值  2[  3]，找右半邊
# 7 介於中間值  2[  3]及最大值  2[  3]，找右半邊
# ##### [  7]不存在 #####
# 請輸入搜尋鍵值(1-100)，輸入-1結束：25
# 25 介於最小值  1[  1]及中間值 25[ 48]，找左半邊
# 25 介於中間值 12[ 23]及最大值 24[ 44]，找右半邊
# 25 介於最小值 13[ 25]及中間值 18[ 36]，找左半邊
# 25 介於最小值 13[ 25]及中間值 15[ 28]，找左半邊
# 在第13個位置找到[ 25]
# 請輸入搜尋鍵值(1-100)，輸入-1結束：-1

# %%
import random

def showData(data_list):
    for i in range(len(data)//5):
        for j in range(5):
            print('%2d[%3d]  ' %(i*5+j+1,data[i*5+j]),end='')
        print()

def bin_search_recursive(data, val, low, high):
    mid=(low+high)//2
    if val==data[mid]:
       return mid        
    else:
        if(low>high):
            return -1
        elif val<data[mid]:
            print('%d 介於最小值%2d[%3d]及中間值%2d[%3d]，找左半邊' \
               %(val,low+1,data[low],mid+1,data[mid]))
            high=mid-1
        else:
            print('%d 介於中間值%2d[%3d]及最大值%2d[%3d]，找右半邊' \
                  %(val,mid+1,data[mid],high+1,data[high]))
            low=mid+1
        return bin_search_recursive(data, val, low, high)

data=[0]*50
for i in range(50):
    data[i]=random.randint(1,100)
data.sort()
print('資料內容：')
showData(data)

while True:
    val=int(input('請輸入搜尋鍵值(1-100)，輸入-1結束：'))
    if val ==-1:
        break
    pos = bin_search_recursive(data,val, 0, len(data)-1)
    if pos==-1:
        print('##### [%3d]不存在 #####' %val)
    else:
        print('在第%2d個位置找到[%3d]' %(pos+1,data[pos]))
# Out:
# 資料內容：
#  1[  3]   2[  3]   3[  4]   4[  4]   5[  5]
#  6[  8]   7[  8]   8[ 10]   9[ 12]  10[ 13]
# 11[ 13]  12[ 14]  13[ 17]  14[ 21]  15[ 22]
# 16[ 22]  17[ 32]  18[ 38]  19[ 40]  20[ 42]
# 21[ 43]  22[ 49]  23[ 49]  24[ 50]  25[ 50]
# 26[ 50]  27[ 53]  28[ 55]  29[ 57]  30[ 59]
# 31[ 67]  32[ 69]  33[ 69]  34[ 70]  35[ 70]
# 36[ 74]  37[ 77]  38[ 78]  39[ 83]  40[ 85]
# 41[ 86]  42[ 87]  43[ 88]  44[ 91]  45[ 91]
# 46[ 92]  47[ 95]  48[ 97]  49[ 98]  50[100]
# 請輸入搜尋鍵值(1-100)，輸入-1結束：22
# 22 介於最小值 1[  3]及中間值25[ 50]，找左半邊
# 22 介於中間值12[ 14]及最大值24[ 50]，找右半邊
# 22 介於最小值13[ 17]及中間值18[ 38]，找左半邊
# 在第15個位置找到[ 22]
# 請輸入搜尋鍵值(1-100)，輸入-1結束：75
# 75 介於中間值25[ 50]及最大值50[100]，找右半邊
# 75 介於最小值26[ 50]及中間值38[ 78]，找左半邊
# 75 介於中間值31[ 67]及最大值37[ 77]，找右半邊
# 75 介於中間值34[ 70]及最大值37[ 77]，找右半邊
# 75 介於中間值36[ 74]及最大值37[ 77]，找右半邊
# 75 介於最小值37[ 77]及中間值37[ 77]，找左半邊
# ##### [ 75]不存在 #####
# 請輸入搜尋鍵值(1-100)，輸入-1結束：10
# 10 介於最小值 1[  3]及中間值25[ 50]，找左半邊
# 10 介於最小值 1[  3]及中間值12[ 14]，找左半邊
# 10 介於中間值 6[  8]及最大值11[ 13]，找右半邊
# 10 介於最小值 7[  8]及中間值 9[ 12]，找左半邊
# 10 介於中間值 7[  8]及最大值 8[ 10]，找右半邊
# 在第 8個位置找到[ 10]
# 請輸入搜尋鍵值(1-100)，輸入-1結束：-1

# %%
cars=["Audi", "Honda", "Mazda", "Ford", "Benz", "Lexus", "BMW"]
print('資料內容：', cars)
while True:
    car=input('請輸入搜尋汽車廠牌，輸入Quit離開：')
    if car == 'Quit':
        break
    for i in range(len(cars)):
        if cars[i]==car:
            print('在第%d個位置找到鍵值[%5s]' %(i+1,cars[i]))
            break
    else:
        print('######[%s]不存在######' %car)
# Out:
# 資料內容： ['Audi', 'Honda', 'Mazda', 'Ford', 'Benz', 'Lexus', 'BMW']
# 請輸入搜尋汽車廠牌，輸入Quit離開：Honda
# 在第2個位置找到鍵值[Honda]
# 請輸入搜尋汽車廠牌，輸入Quit離開：Quit

# %%
import random

def showData(data_list):
    for i in range(len(data)//5):
        for j in range(5):
            print('%2d[%3d]  ' %(i*5+j+1,data[i*5+j]),end='')
        print()

def bin_search(data, val):
    low, high = 0, len(data)-1
    mid = -1
    while not low>high:
        mid=(low+high)//2
        if val<data[mid]:
            print('%d 介於最小值 %2d[%3d]及中間值 %2d[%3d]，找左半邊' \
                   %(val,low+1,data[low],mid+1,data[mid]))
            high=mid-1
        elif val>data[mid]:
            print('%d 介於中間值 %2d[%3d]及最大值 %2d[%3d]，找右半邊' \
                  %(val,mid+1,data[mid],high+1,data[high]))
            low=mid+1
        else:
            return mid
    return -1

data=[]
while(len(data)<50):
    randNum = random.randint(1,100)
    if(randNum not in data):
        data.append(randNum)

data.sort()
print('資料內容：')
showData(data)

while True:
    val=int(input('請輸入搜尋鍵值(1-100)，輸入-1結束：'))
    if val ==-1:
        break
    pos=bin_search(data,val)
    if pos==-1:
        print('##### [%3d]不存在 #####' %val)
    else:
        print('在第%2d個位置找到[%3d]' %(pos+1,data[pos]))

# %%
import random

def showData(data_list):
    for i in range(len(data)//5):
        for j in range(5):
            print('%2d[%3d]  ' %(i*5+j+1,data[i*5+j]),end='')
        print()

def bin_search_recursive(data, val, low, high):
    mid=(low+high)//2
    if val==data[mid]:
       return mid        
    else:
        if(low>high):
            return -1
        elif val<data[mid]:
            print('%d 介於最小值%2d[%3d]及中間值%2d[%3d]，找左半邊' \
               %(val,low+1,data[low],mid+1,data[mid]))
            high=mid-1
        else:
            print('%d 介於中間值%2d[%3d]及最大值%2d[%3d]，找右半邊' \
                  %(val,mid+1,data[mid],high+1,data[high]))
            low=mid+1
        return bin_search_recursive(data, val, low, high)

data=[0]*50
for i in range(50):
    data[i]=random.randint(1,100)
data.sort()
print('資料內容：')
showData(data)

while True:
    val=int(input('請輸入搜尋鍵值(1-100)，輸入-1結束：'))
    if val ==-1:
        break
    pos = bin_search_recursive(data,val, 0, len(data)-1)
    if pos==-1:
        print('##### [%3d]不存在 #####' %val)
    else:
        print('在第%2d個位置找到[%3d]' %(pos+1,data[pos]))

# %% [markdown]
# ## 二分搜尋練習 作業

# %%
def showdata(data_list):
    print('[', end='')
    for i in range(len(data_list)):
        print(data_list[i],end=' ')
    print(']')
    
class Student:
    def __init__(self, name, age, gpa):
        self.name = name
        self.age = age
        self.gpa = gpa
    def __lt__(self, student2):
        if self.gpa<student2.gpa:
            return True
        else:
            return False
    def __gt__(self, student2):
        if self.gpa>student2.gpa:
            return True
        else:
            return False
    def __str__(self):
        return '%5s(%d,%.1f)'%(self.name,self.age,self.gpa)

def bin_search(data, score):
    low, high = 0, len(data)-1
    mid = -1
    while not low>high:
        mid=(low+high)//2
        if score>data[mid].gpa:
            print('%d 介於最小值 %2d[%s]及中間值 %2d[%s]，找左半邊' \
                   %(score,low+1,data[low],mid+1,data[mid]))
            high=mid-1
        elif score<data[mid].gpa:
            print('%d 介於中間值 %2d[%s]及最大值 %2d[%s]，找右半邊' \
                  %(score,mid+1,data[mid],high+1,data[high]))
            low=mid+1
        else:
            return mid
    return -1

data=[Student('Amy', 15, 4.2),
      Student('Bill', 16, 3.8),
      Student('Chris', 13, 4.0),
      Student('David', 19, 4.8),
      Student('Ed', 17, 2.6)]

data.sort(reverse=True)
print('資料內容：', end='')
showdata(data)

while True:
    score=float(input('請輸入搜尋成績，輸入-1結束：'))
    if score == -1.0:
        break
    pos=bin_search(data,score)
    if pos==-1:
        print('##### 沒有成績[%.1f]的學生 #####' %score)
    else:
        print('在第%2d個位置找到學生[%s]' %(pos+1, str(data[pos])))
# Out:
# 資料內容：[David(19,4.8)   Amy(15,4.2) Chris(13,4.0)  Bill(16,3.8)    Ed(17,2.6) ]
# 請輸入搜尋成績，輸入-1結束：4.2
# 4 介於最小值  1[David(19,4.8)]及中間值  3[Chris(13,4.0)]，找左半邊
# 4 介於中間值  1[David(19,4.8)]及最大值  2[  Amy(15,4.2)]，找右半邊
# 在第 2個位置找到學生[  Amy(15,4.2)]
# 請輸入搜尋成績，輸入-1結束：-1

# %%
import random

def showData(data_list):
    for i in range(len(data)//5):
        for j in range(5):
            print('%2d[%3d]  ' %(i*5+j+1,data[i*5+j]),end='') #第i次5 + j+1
        print()

def interpolation_search(data,val):
    low, high = 0, len(data)-1
    mid = -1
    while low < high:
        mid=low+(val-data[low])*(high-low)//(data[high]-data[low])          #內插法公式
        if(mid<low or mid>high):
            return -1
        if val < data[mid]:
            print('%d 介於位置 %d[%3d]及內插值 %d[%3d]，找左半邊' \
                  %(val,low+1,data[low],mid+1,data[mid]))
            high=mid-1
        elif val > data[mid]:
            print('%d 介於內插值 %d[%3d] 及位置 %d[%3d]，找右半邊' \
                  %(val,mid+1,data[mid],high+1,data[high]))
            low=mid+1
        else:
            return mid
    return -1

data=[]
while(len(data)<50):
    randNum = random.randint(1,100)
    if(randNum not in data):
        data.append(randNum)

data.sort()
print('資料內容：')
showData(data)

while True:
    val=int(input('請輸入搜尋鍵值(1-100)，輸入-1結束：'))
    if val==-1:
        break
    pos=interpolation_search(data,val)
    if pos==-1:
         print('##### [%3d]不存在 #####' %val)
    else:
        print('在第 %2d個位置找到 [%3d]' %(pos+1,data[pos]))
# Out:
# 資料內容：
#  1[  6]   2[  8]   3[  9]   4[ 10]   5[ 11]
#  6[ 12]   7[ 13]   8[ 14]   9[ 17]  10[ 25]
# 11[ 28]  12[ 31]  13[ 32]  14[ 33]  15[ 35]
# 16[ 36]  17[ 38]  18[ 39]  19[ 44]  20[ 45]
# 21[ 46]  22[ 47]  23[ 48]  24[ 50]  25[ 52]
# 26[ 53]  27[ 55]  28[ 56]  29[ 58]  30[ 61]
# 31[ 62]  32[ 65]  33[ 66]  34[ 69]  35[ 71]
# 36[ 73]  37[ 75]  38[ 77]  39[ 81]  40[ 82]
# 41[ 84]  42[ 86]  43[ 87]  44[ 89]  45[ 90]
# 46[ 93]  47[ 94]  48[ 95]  49[ 96]  50[ 97]
# 請輸入搜尋鍵值(1-100)，輸入-1結束：9
# 9 介於內插值 2[  8] 及位置 50[ 97]，找右半邊
# 在第  3個位置找到 [  9]
# 請輸入搜尋鍵值(1-100)，輸入-1結束：-1

# %%
def showdata(data_list):
    print('[', end='')
    for i in range(len(data_list)):
        print(data_list[i],end=' ')
    print(']')

class Student:
    def __init__(self, name, age, gpa):
        self.name = name
        self.age = age
        self.gpa = gpa
    def __lt__(self, student2):
        if self.age<student2.age:
            return True
        else:
            return False
    def __gt__(self, student2):
        if self.age>student2.age:
            return True
        else:
            return False
    def __str__(self):
        return '%5s(%d,%.1f)'%(self.name,self.age,self.gpa)

def interpolation_search(data,val):
    low, high = 0, len(data)-1
    mid = -1
    while low < high:
        mid=low+(high-low)*(val-data[low].age)//(data[high].age-data[low].age)          #內插法公式
        if(mid<low or mid>high):
            return -1
        if val < data[mid].age:
            print('%d 介於位置 %d[%s]及內插值 %d[%s]，找左半邊' \
                  %(val,low+1,data[low],mid+1,data[mid]))
            high=mid-1
        elif val > data[mid].age:
            print('%d 介於內插值 %d[%s] 及位置 %d[%s]，找右半邊' \
                  %(val,mid+1,data[mid],high+1,data[high]))
            low=mid+1
        else:
            return mid
    return -1

data=[Student('Amy', 15, 4.2),
      Student('Bill', 16, 3.8),
      Student('Chris', 13, 4.0),
      Student('David', 19, 4.8),
      Student('Ed', 17, 2.6)]

data.sort()
print('資料內容：', end='')
showdata(data)

while True:
    val=int(input('請輸入搜尋年紀，輸入-1結束：'))
    if val==-1:
        break
    pos=interpolation_search(data,val)
    if pos==-1:
         print('##### 年紀[%d]學生不存在 #####' %val)
    else:
        print('在第 %2d個位置找到 [%s]' %(pos+1,data[pos]))
